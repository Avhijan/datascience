# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
# Load dataset

# %%
# Load dataset
def load_repositary1(file_path):
  return pd.read_csv(file_path)


df = load_repositary1("./Health_heart_experimental.csv")
df.head(5)
# Out:
#    Unnamed: 0  age  sex  SysBP  DiaBP   HR  weightKg  heightCm   BMI  \
# 0           0   64    1    141     96  128        69       147  32.0
# 1           1   21    1    109    100  106        48       150  21.0
# 2           2   30    0    112     73  126        69       183  21.0
# 3           3   35    1    106     90  130        45       149  20.0
# 4           4   39    0    140     90  112        92       166  33.0
#
#    indication
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ###
# PIE-CHART

# %% [markdown]
# The above pichart shows the portion of male and female in the test. It shows that the there is only a slight difference between the number of the two sexes

# %%
sns.lineplot(x=df['age'],y=df['BMI'])
# Out:
# <Axes: xlabel='age', ylabel='BMI'>

# %% [markdown]
# ###
# Line-Chart

# %% [markdown]
# The above line-chart shows the graph between age and BMI

# %%
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(x='sex',y='age',hue='indication',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.hist(df['age'])
# Out:
# (array([7396., 7195., 7167., 7060., 7164., 7136., 7059., 7043., 7279.,
#         7261.]),
#  array([20. , 24.9, 29.8, 34.7, 39.6, 44.5, 49.4, 54.3, 59.2, 64.1, 69. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df['age'], kind="hist", kde=True)

# %%
sns.scatterplot(x='heightCm', y='weightKg',hue='sex', style='indication',data=df)
plt.show()
